# %% [markdown]
# # Stroke Prognosis: Prueba de los Modelos
#
# <p>
# Curso de Minería de Datos <br>
# Autor: Cristian Pavez Hormazábal
# </p>

# %%
# Importación de librerías
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

import sklearn as sk
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, ExtraTreesClassifier, ExtraTreesClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier


import yellowbrick as yb
from yellowbrick.classifier import ConfusionMatrix

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 19
#      15 from xgboost import XGBClassifier
#      16 from lightgbm import LGBMClassifier
# ---> 19 import yellowbrick as yb
#      20 from yellowbrick.classifier import ConfusionMatrix
#      22 import tensorflow as tf
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\yellowbrick\__init__.py:31
#      28 from .version import get_version, __version_info__
#      30 # Import the style management functions
# ---> 31 from .style.rcmod import reset_defaults, reset_orig
#      32 from .style.rcmod import set_aesthetic, set_style, set_palette
#      33 from .style.palettes import color_palette, set_color_codes
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\yellowbrick\style\__init__.py:20
#      12 """
#      13 Manage the style and aesthetic of the yellowbrick library.
#      14 """
#      16 ##########################################################################
#      17 ## Imports
#      18 ##########################################################################
# ---> 20 from .colors import *
#      21 from .palettes import *
#      22 from .rcmod import *
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\yellowbrick\style\colors.py:33
#      29 from yellowbrick.exceptions import YellowbrickValueError
#      32 # Check to see if matplotlib is at least sorta up to date
# ---> 33 from distutils.version import LooseVersion
#      35 mpl_ge_150 = LooseVersion(mpl.__version__) >= "1.5.0"
#      38 ##########################################################################
#      39 ## Color Utilities
#      40 ##########################################################################
#
# ModuleNotFoundError: No module named 'distutils'

# %%
# Importación de datos
dataset = pd.read_csv("all-data.csv")

# Formateo de los datos
dataset.drop("id", axis=1, inplace=True)
dataset['gender'] = dataset['gender'].map({'Male': 1, 'Female': 0, 'Other': 2})
dataset['ever_married'] = dataset['ever_married'].map({'Yes': 1, 'No': 0})
dataset['work_type'] = dataset['work_type'].map({'Private': 4, 'Self-employed': 2, 'Govt_job': 3, 'children': 1, 'Never_worked': 0})
dataset['Residence_type'] = dataset['Residence_type'].map({'Rural': 0, 'Urban': 1})
dataset['smoking_status'] = dataset['smoking_status'].map({'Unknown': 0, 'never smoked': 1, 'formerly smoked': 2, 'smokes': 3})

# Eliminar filas con valores perdidos
dataset_no_bmi = dataset.drop("bmi", axis=1)
dataset = dataset.dropna()

# Dividir el dataset en personas con y sin stroke
stroke_data = dataset[dataset['stroke'] == 1]
no_stroke_data = dataset[dataset['stroke'] == 0]

# Sobre-representar los datos de stroke (multiplicar por 22)
stroke_data_overrepresented = pd.concat([stroke_data] * 22, ignore_index=True)

# Combinar los datasets
balanced_dataset = pd.concat([stroke_data_overrepresented, no_stroke_data], ignore_index=True)

# Mezclar los datos para evitar orden
balanced_dataset = balanced_dataset.sample(frac=1, random_state=42).reset_index(drop=True)

# Segundo Balanceo
# Dividir el dataset en personas con y sin stroke
stroke_data = dataset_no_bmi[dataset_no_bmi['stroke'] == 1]
no_stroke_data = dataset_no_bmi[dataset_no_bmi['stroke'] == 0]

# Sobre-representar los datos de stroke
stroke_data_overrepresented = pd.concat([stroke_data] * 19, ignore_index=True)

# Combinar los datasets
balanced_dataset2 = pd.concat([stroke_data_overrepresented, no_stroke_data], ignore_index=True)

# Mezclar los datos para evitar orden
balanced_dataset2 = balanced_dataset2.sample(frac=1, random_state=42).reset_index(drop=True)

# Verificar el balance
print('Dataset original:', dataset['stroke'].value_counts())
print('Dataset sin IMC:', dataset_no_bmi['stroke'].value_counts())
print('Dataset original balanceado:', balanced_dataset['stroke'].value_counts())
print('Dataset sin IMC balanceado:', balanced_dataset2['stroke'].value_counts())
# Out:
# Dataset original: stroke
# 0    4700
# 1     209
# Name: count, dtype: int64
# Dataset sin IMC: stroke
# 0    4861
# 1     249
# Name: count, dtype: int64
# Dataset original balanceado: stroke
# 0    4700
# 1    4598
# Name: count, dtype: int64
# Dataset sin IMC balanceado: stroke
# 0    4861
# 1    4731
# Name: count, dtype: int64

# %%
training_columns = ['gender', 'age', 'hypertension', 'heart_disease', 'ever_married', 'work_type', 'Residence_type', 'avg_glucose_level', 'bmi', 'smoking_status']

x1 = dataset[training_columns]
y1 = dataset['stroke']

x2 = balanced_dataset[training_columns]
y2 = balanced_dataset['stroke']

training_columns = ['gender', 'age', 'hypertension', 'heart_disease', 'ever_married', 'work_type', 'Residence_type', 'avg_glucose_level', 'smoking_status']

x3 = dataset_no_bmi[training_columns]
y3 = dataset_no_bmi['stroke']

x4 = balanced_dataset2[training_columns]
y4 = balanced_dataset2['stroke']


x1_train, x1_test, y1_train, y1_test = sk.model_selection.train_test_split(x1, y1, random_state = 42, test_size=0.2, shuffle=True)
x2_train, x2_test, y2_train, y2_test = sk.model_selection.train_test_split(x2, y2, random_state = 42, test_size=0.2, shuffle=True)
x3_train, x3_test, y3_train, y3_test = sk.model_selection.train_test_split(x3, y3, random_state = 42, test_size=0.2, shuffle=True)
x4_train, x4_test, y4_train, y4_test = sk.model_selection.train_test_split(x4, y4, random_state = 42, test_size=0.2, shuffle=True)

# %%
naive_bayes = sk.naive_bayes.GaussianNB()
naive_bayes.fit(x1_train, y1_train)
previsoes = naive_bayes.predict(x1_test)

cm = yb.classifier.ConfusionMatrix(naive_bayes)
cm.fit(x1_train, y1_train)
score_naive_gaussian = cm.score(x1_test, y1_test)
print(score_naive_gaussian)
cm.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# 0.8706720977596741
# <Axes: title={'center': 'GaussianNB Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
naive_bayes = sk.naive_bayes.GaussianNB()
naive_bayes.fit(x2_train, y2_train)
previsoes = naive_bayes.predict(x2_test)

cm = yb.classifier.ConfusionMatrix(naive_bayes)
cm.fit(x2_train, y2_train)
score_naive_gaussian = cm.score(x2_test, y2_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.7559139784946236
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'GaussianNB Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
naive_bayes = sk.naive_bayes.GaussianNB()
naive_bayes.fit(x3_train, y3_train)
previsoes = naive_bayes.predict(x3_test)

cm = yb.classifier.ConfusionMatrix(naive_bayes)
cm.fit(x3_train, y3_train)
score_naive_gaussian = cm.score(x3_test, y3_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.8669275929549902
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'GaussianNB Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
naive_bayes = sk.naive_bayes.GaussianNB()
naive_bayes.fit(x4_train, y4_train)
previsoes = naive_bayes.predict(x4_test)

cm = yb.classifier.ConfusionMatrix(naive_bayes)
cm.fit(x4_train, y4_train)
score_naive_gaussian = cm.score(x4_test, y4_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.7269411151641479
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'GaussianNB Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
naive_bayes = sk.naive_bayes.BernoulliNB()
naive_bayes.fit(x1_train, y1_train)
previsoes = naive_bayes.predict(x1_test)

cm = yb.classifier.ConfusionMatrix(naive_bayes)
cm.fit(x1_train, y1_train)
score_naive_gaussian = cm.score(x1_test, y1_test)
print(score_naive_gaussian)
cm.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but BernoulliNB was fitted with feature names
#   warnings.warn(
# 0.9429735234215886
# <Axes: title={'center': 'BernoulliNB Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
naive_bayes = sk.naive_bayes.BernoulliNB()
naive_bayes.fit(x2_train, y2_train)
previsoes = naive_bayes.predict(x2_test)

cm = yb.classifier.ConfusionMatrix(naive_bayes)
cm.fit(x2_train, y2_train)
score_naive_gaussian = cm.score(x2_test, y2_test)
print(score_naive_gaussian)
cm.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but BernoulliNB was fitted with feature names
#   warnings.warn(
# 0.656989247311828
# <Axes: title={'center': 'BernoulliNB Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
naive_bayes = sk.naive_bayes.BernoulliNB()
naive_bayes.fit(x3_train, y3_train)
previsoes = naive_bayes.predict(x3_test)

cm = yb.classifier.ConfusionMatrix(naive_bayes)
cm.fit(x3_train, y3_train)
score_naive_gaussian = cm.score(x3_test, y3_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.9393346379647749
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but BernoulliNB was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'BernoulliNB Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
naive_bayes = sk.naive_bayes.BernoulliNB()
naive_bayes.fit(x4_train, y4_train)
previsoes = naive_bayes.predict(x4_test)

cm = yb.classifier.ConfusionMatrix(naive_bayes)
cm.fit(x4_train, y4_train)
score_naive_gaussian = cm.score(x4_test, y4_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.6206357477853048
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but BernoulliNB was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'BernoulliNB Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
tree = sk.tree.DecisionTreeClassifier()
tree.fit(x1_train, y1_train)
previsoes = tree.predict(x1_test)

cm = yb.classifier.ConfusionMatrix(tree)
cm.fit(x1_train, y1_train)
score_naive_gaussian = cm.score(x1_test, y1_test)
print(score_naive_gaussian)
cm.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 0.9164969450101833
# <Axes: title={'center': 'DecisionTreeClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
tree = sk.tree.DecisionTreeClassifier()
tree.fit(x2_train, y2_train)
previsoes = tree.predict(x2_test)

cm = yb.classifier.ConfusionMatrix(tree)
cm.fit(x2_train, y2_train)
score_naive_gaussian = cm.score(x2_test, y2_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.9731182795698925
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'DecisionTreeClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
tree = sk.tree.DecisionTreeClassifier()
tree.fit(x3_train, y3_train)
previsoes = tree.predict(x3_test)

cm = yb.classifier.ConfusionMatrix(tree)
cm.fit(x3_train, y3_train)
score_naive_gaussian = cm.score(x3_test, y3_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.9119373776908023
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'DecisionTreeClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
tree = sk.tree.DecisionTreeClassifier()
tree.fit(x4_train, y4_train)
previsoes = tree.predict(x4_test)

cm = yb.classifier.ConfusionMatrix(tree)
cm.fit(x4_train, y4_train)
score_naive_gaussian = cm.score(x4_test, y4_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.9807191245440333
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'DecisionTreeClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
# Loop to test all k values from 1 to 30
k_values = range(1, 31)
scores = []
recall = []
precision = []
for k in k_values:
    knn = sk.neighbors.KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=2)
    knn.fit(x1_train, y1_train)
    previsoes = knn.predict(x1_test)
    
    # Calculate and store the score
    score = knn.score(x1_test, y1_test)
    recall_score = sk.metrics.recall_score(y1_test, previsoes)
    precision_score = sk.metrics.precision_score(y1_test, previsoes)
    scores.append(score)
    recall.append(recall_score)
    precision.append(precision_score)
    
    """
    # Visualize the confusion matrix
    cm = ConfusionMatrix(knn)
    cm.fit(x1_train, y1_train)
    cm.score(x1_test, y1_test)
    cm.show()
    
    # Print classification report
    print(f"Classification Report for k={k}:")
    print(classification_report(y1_test, previsoes))
    """
    
plt.figure(figsize=(10, 6))
plt.plot(k_values, scores, marker='o', label='Accuracy', color='blue')
plt.plot(k_values, recall, marker='o', label='Recall', color='green')
plt.plot(k_values, precision, marker='o', label='Precision', color='red')
plt.title('KNN Performance for Different k Values')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Score')
plt.grid(True)
plt.legend(title='Métrica', loc='best')
plt.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
knn = sk.neighbors.KNeighborsClassifier(n_neighbors = 1, metric = 'minkowski', p = 2)
knn.fit(x1_train, y1_train)
previsoes = knn.predict(x1_test)

cm = yb.classifier.ConfusionMatrix(knn)
cm.fit(x1_train, y1_train)
score_naive_gaussian = cm.score(x1_test, y1_test)
print(score_naive_gaussian)
cm.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 0.9134419551934827
# <Axes: title={'center': 'KNeighborsClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
# Loop to test all k values from 1 to 30
k_values = range(1, 31)
scores = []
recall = []
precision = []
for k in k_values:
    knn = sk.neighbors.KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=2)
    knn.fit(x2_train, y2_train)
    previsoes = knn.predict(x2_test)
    
    # Calculate and store the score
    score = knn.score(x2_test, y2_test)
    recall_score = sk.metrics.recall_score(y2_test, previsoes)
    precision_score = sk.metrics.precision_score(y2_test, previsoes)
    scores.append(score)
    recall.append(recall_score)
    precision.append(precision_score)
    
    
plt.figure(figsize=(10, 6))
plt.plot(k_values, scores, marker='o', label='Accuracy', color='blue')
plt.plot(k_values, recall, marker='o', label='Recall', color='green')
plt.plot(k_values, precision, marker='o', label='Precision', color='red')
plt.title('KNN Performance for Different k Values')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Score')
plt.grid(True)
plt.legend(title='Métrica', loc='best')
plt.show()

# %%
knn = sk.neighbors.KNeighborsClassifier(n_neighbors = 1, metric = 'minkowski', p = 2)
knn.fit(x2_train, y2_train)
previsoes = knn.predict(x2_test)

cm = yb.classifier.ConfusionMatrix(knn)
cm.fit(x2_train, y2_train)
score_naive_gaussian = cm.score(x2_test, y2_test)
print(score_naive_gaussian)
cm.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 0.9693548387096774
# <Axes: title={'center': 'KNeighborsClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
# Loop to test all k values from 1 to 30
k_values = range(1, 31)
scores = []
recall = []
precision = []
for k in k_values:
    knn = sk.neighbors.KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=2)
    knn.fit(x3_train, y3_train)
    previsoes = knn.predict(x3_test)
    
    # Calculate and store the score
    score = knn.score(x3_test, y3_test)
    recall_score = sk.metrics.recall_score(y3_test, previsoes)
    precision_score = sk.metrics.precision_score(y3_test, previsoes)
    scores.append(score)
    recall.append(recall_score)
    precision.append(precision_score)
    
    
plt.figure(figsize=(10, 6))
plt.plot(k_values, scores, marker='o', label='Accuracy', color='blue')
plt.plot(k_values, recall, marker='o', label='Recall', color='green')
plt.plot(k_values, precision, marker='o', label='Precision', color='red')
plt.title('KNN Performance for Different k Values')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Score')
plt.grid(True)
plt.legend(title='Métrica', loc='best')
plt.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
knn = sk.neighbors.KNeighborsClassifier(n_neighbors = 3, metric = 'minkowski', p = 2)
knn.fit(x3_train, y3_train)
previsoes = knn.predict(x3_test)

cm = yb.classifier.ConfusionMatrix(knn)
cm.fit(x3_train, y3_train)
score_naive_gaussian = cm.score(x3_test, y3_test)
print(score_naive_gaussian)
cm.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 0.9295499021526419
# <Axes: title={'center': 'KNeighborsClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
# Loop to test all k values from 1 to 30
k_values = range(1, 31)
scores = []
recall = []
precision = []
for k in k_values:
    knn = sk.neighbors.KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=2)
    knn.fit(x4_train, y4_train)
    previsoes = knn.predict(x4_test)
    
    # Calculate and store the score
    score = knn.score(x4_test, y4_test)
    recall_score = sk.metrics.recall_score(y4_test, previsoes)
    precision_score = sk.metrics.precision_score(y4_test, previsoes)
    scores.append(score)
    recall.append(recall_score)
    precision.append(precision_score)
    
    
plt.figure(figsize=(10, 6))
plt.plot(k_values, scores, marker='o', label='Accuracy', color='blue')
plt.plot(k_values, recall, marker='o', label='Recall', color='green')
plt.plot(k_values, precision, marker='o', label='Precision', color='red')
plt.title('KNN Performance for Different k Values')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Score')
plt.grid(True)
plt.legend(title='Métrica', loc='best')
plt.show()

# %%
knn = sk.neighbors.KNeighborsClassifier(n_neighbors = 4, metric = 'minkowski', p = 2)
knn.fit(x4_train, y4_train)
previsoes = knn.predict(x4_test)

cm = yb.classifier.ConfusionMatrix(knn)
cm.fit(x4_train, y4_train)
score_naive_gaussian = cm.score(x4_test, y4_test)
print(score_naive_gaussian)
cm.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 0.9510161542470037
# <Axes: title={'center': 'KNeighborsClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
# Convertir las etiquetas a formato categórico
num_classes = len(y1.unique())
y1_train_categorical = to_categorical(y1_train, num_classes)
y1_test_categorical = to_categorical(y1_test, num_classes)

# Crear el modelo
model = Sequential([
    Dense(128, activation='relu', input_shape=(x1_train.shape[1],)),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])

# Compilar el modelo
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Entrenar el modelo
history = model.fit(x1_train, y1_train_categorical, epochs=50, batch_size=32, validation_split=0.2)

# Generar predicciones
y1_pred = model.predict(x1_test)
y1_pred_classes = np.argmax(y1_pred, axis=1)  # Convertir predicciones a clases
y1_test_classes = np.argmax(y1_test_categorical, axis=1)  # Convertir etiquetas reales a clases

# Crear la matriz de confusión
cm = confusion_matrix(y1_test_classes, y1_pred_classes)

# Visualizar la matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(num_classes))
disp.plot(cmap='Blues')
plt.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9073 - loss: 1.7097 - val_accuracy: 0.9618 - val_loss: 0.2762
# Epoch 2/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9073 - loss: 1.7097 - val_accuracy: 0.9618 - val_loss: 0.2762
# Epoch 2/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9131 - loss: 0.5725 - val_accuracy: 0.9618 - val_loss: 0.1738
# Epoch 3/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9131 - loss: 0.5725 - val_accuracy: 0.9618 - val_loss: 0.1738
# Epoch 3/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9463 - loss: 0.2937 - val_accuracy: 0.9618 - val_loss: 0.1866
# Epoch 4/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9463 - loss: 0.2937 - val_accuracy: 0.9618 - val_loss: 0.1866
# Epoch 4/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9441 - loss: 0.2366 - val_accuracy: 0.9618 - val_loss: 0.1754
# Epoch 5/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9441 - loss: 0.2366 - val_accuracy: 0.9618 - val_loss: 0.1754
# Epoch 5/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9591 - loss: 0.1816 - val_accuracy: 0.9618 - val_loss: 0.1906
# Epoch 6/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9591 - loss: 0.1816 - val_accuracy: 0.9618 - val_loss: 0.1906
# Epoch 6/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9606 - loss: 0.1915 - val_accuracy: 0.9618 - val_loss: 0.1750
# Epoch 7/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9606 - loss: 0.1915 - val_accuracy: 0.9618 - val_loss: 0.1750
# Epoch 7/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9573 - loss: 0.2235 - val_accuracy: 0.9618 - val_loss: 0.1892
# Epoch 8/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9573 - loss: 0.2235 - val_accuracy: 0.9618 - val_loss: 0.1892
# Epoch 8/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9567 - loss: 0.1944 - val_accuracy: 0.9618 - val_loss: 0.1551
# Epoch 9/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9567 - loss: 0.1944 - val_accuracy: 0.9618 - val_loss: 0.1551
# Epoch 9/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9566 - loss: 0.1831 - val_accuracy: 0.9618 - val_loss: 0.1614
# Epoch 10/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9566 - loss: 0.1831 - val_accuracy: 0.9618 - val_loss: 0.1614
# Epoch 10/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9558 - loss: 0.1918 - val_accuracy: 0.9618 - val_loss: 0.1538
# Epoch 11/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9558 - loss: 0.1918 - val_accuracy: 0.9618 - val_loss: 0.1538
# Epoch 11/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9601 - loss: 0.1626 - val_accuracy: 0.9618 - val_loss: 0.1549
# Epoch 12/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9601 - loss: 0.1626 - val_accuracy: 0.9618 - val_loss: 0.1549
# Epoch 12/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9592 - loss: 0.1597 - val_accuracy: 0.9618 - val_loss: 0.1514
# Epoch 13/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9592 - loss: 0.1597 - val_accuracy: 0.9618 - val_loss: 0.1514
# Epoch 13/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9590 - loss: 0.1816 - val_accuracy: 0.9618 - val_loss: 0.1682
# Epoch 14/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9590 - loss: 0.1816 - val_accuracy: 0.9618 - val_loss: 0.1682
# Epoch 14/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9648 - loss: 0.1509 - val_accuracy: 0.9618 - val_loss: 0.1767
# Epoch 15/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9648 - loss: 0.1509 - val_accuracy: 0.9618 - val_loss: 0.1767
# Epoch 15/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9547 - loss: 0.1908 - val_accuracy: 0.9618 - val_loss: 0.1501
# Epoch 16/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9547 - loss: 0.1908 - val_accuracy: 0.9618 - val_loss: 0.1501
# Epoch 16/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9588 - loss: 0.1673 - val_accuracy: 0.9618 - val_loss: 0.1511
# Epoch 17/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9588 - loss: 0.1673 - val_accuracy: 0.9618 - val_loss: 0.1511
# Epoch 17/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9544 - loss: 0.1835 - val_accuracy: 0.9618 - val_loss: 0.1480
# Epoch 18/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9544 - loss: 0.1835 - val_accuracy: 0.9618 - val_loss: 0.1480
# Epoch 18/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9562 - loss: 0.1786 - val_accuracy: 0.9618 - val_loss: 0.1488
# Epoch 19/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9562 - loss: 0.1786 - val_accuracy: 0.9618 - val_loss: 0.1488
# Epoch 19/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9603 - loss: 0.1591 - val_accuracy: 0.9618 - val_loss: 0.1489
# Epoch 20/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9603 - loss: 0.1591 - val_accuracy: 0.9618 - val_loss: 0.1489
# Epoch 20/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9590 - loss: 0.1567 - val_accuracy: 0.9618 - val_loss: 0.1530
# Epoch 21/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9590 - loss: 0.1567 - val_accuracy: 0.9618 - val_loss: 0.1530
# Epoch 21/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9619 - loss: 0.1564 - val_accuracy: 0.9618 - val_loss: 0.1481
# Epoch 22/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9619 - loss: 0.1564 - val_accuracy: 0.9618 - val_loss: 0.1481
# Epoch 22/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9626 - loss: 0.1467 - val_accuracy: 0.9618 - val_loss: 0.1499
# Epoch 23/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9626 - loss: 0.1467 - val_accuracy: 0.9618 - val_loss: 0.1499
# Epoch 23/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9620 - loss: 0.1532 - val_accuracy: 0.9618 - val_loss: 0.1565
# Epoch 24/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9620 - loss: 0.1532 - val_accuracy: 0.9618 - val_loss: 0.1565
# Epoch 24/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9599 - loss: 0.1543 - val_accuracy: 0.9618 - val_loss: 0.1475
# Epoch 25/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9599 - loss: 0.1543 - val_accuracy: 0.9618 - val_loss: 0.1475
# Epoch 25/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9591 - loss: 0.1476 - val_accuracy: 0.9618 - val_loss: 0.1557
# Epoch 26/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9591 - loss: 0.1476 - val_accuracy: 0.9618 - val_loss: 0.1557
# Epoch 26/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9609 - loss: 0.1457 - val_accuracy: 0.9618 - val_loss: 0.1463
# Epoch 27/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9609 - loss: 0.1457 - val_accuracy: 0.9618 - val_loss: 0.1463
# Epoch 27/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9553 - loss: 0.1699 - val_accuracy: 0.9618 - val_loss: 0.1475
# Epoch 28/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9553 - loss: 0.1699 - val_accuracy: 0.9618 - val_loss: 0.1475
# Epoch 28/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9589 - loss: 0.1558 - val_accuracy: 0.9618 - val_loss: 0.1462
# Epoch 29/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9589 - loss: 0.1558 - val_accuracy: 0.9618 - val_loss: 0.1462
# Epoch 29/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9620 - loss: 0.1483 - val_accuracy: 0.9618 - val_loss: 0.1470
# Epoch 30/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9620 - loss: 0.1483 - val_accuracy: 0.9618 - val_loss: 0.1470
# Epoch 30/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9537 - loss: 0.1590 - val_accuracy: 0.9618 - val_loss: 0.1449
# Epoch 31/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9537 - loss: 0.1590 - val_accuracy: 0.9618 - val_loss: 0.1449
# Epoch 31/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9583 - loss: 0.1526 - val_accuracy: 0.9618 - val_loss: 0.1469
# Epoch 32/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9583 - loss: 0.1526 - val_accuracy: 0.9618 - val_loss: 0.1469
# Epoch 32/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9551 - loss: 0.1640 - val_accuracy: 0.9618 - val_loss: 0.1455
# Epoch 33/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9551 - loss: 0.1640 - val_accuracy: 0.9618 - val_loss: 0.1455
# Epoch 33/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9609 - loss: 0.1458 - val_accuracy: 0.9618 - val_loss: 0.1455
# Epoch 34/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9609 - loss: 0.1458 - val_accuracy: 0.9618 - val_loss: 0.1455
# Epoch 34/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9590 - loss: 0.1537 - val_accuracy: 0.9618 - val_loss: 0.1454
# Epoch 35/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9590 - loss: 0.1537 - val_accuracy: 0.9618 - val_loss: 0.1454
# Epoch 35/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9582 - loss: 0.1505 - val_accuracy: 0.9618 - val_loss: 0.1477
# Epoch 36/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9582 - loss: 0.1505 - val_accuracy: 0.9618 - val_loss: 0.1477
# Epoch 36/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9658 - loss: 0.1329 - val_accuracy: 0.9618 - val_loss: 0.1493
# Epoch 37/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9658 - loss: 0.1329 - val_accuracy: 0.9618 - val_loss: 0.1493
# Epoch 37/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9595 - loss: 0.1537 - val_accuracy: 0.9618 - val_loss: 0.1444
# Epoch 38/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9595 - loss: 0.1537 - val_accuracy: 0.9618 - val_loss: 0.1444
# Epoch 38/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9584 - loss: 0.1474 - val_accuracy: 0.9618 - val_loss: 0.1443
# Epoch 39/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9584 - loss: 0.1474 - val_accuracy: 0.9618 - val_loss: 0.1443
# Epoch 39/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9569 - loss: 0.1645 - val_accuracy: 0.9618 - val_loss: 0.1438
# Epoch 40/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9569 - loss: 0.1645 - val_accuracy: 0.9618 - val_loss: 0.1438
# Epoch 40/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9580 - loss: 0.1518 - val_accuracy: 0.9618 - val_loss: 0.1464
# Epoch 41/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9580 - loss: 0.1518 - val_accuracy: 0.9618 - val_loss: 0.1464
# Epoch 41/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9533 - loss: 0.1643 - val_accuracy: 0.9618 - val_loss: 0.1455
# Epoch 42/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9533 - loss: 0.1643 - val_accuracy: 0.9618 - val_loss: 0.1455
# Epoch 42/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9587 - loss: 0.1486 - val_accuracy: 0.9618 - val_loss: 0.1443
# Epoch 43/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9587 - loss: 0.1486 - val_accuracy: 0.9618 - val_loss: 0.1443
# Epoch 43/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9670 - loss: 0.1280 - val_accuracy: 0.9618 - val_loss: 0.1485
# Epoch 44/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9670 - loss: 0.1280 - val_accuracy: 0.9618 - val_loss: 0.1485
# Epoch 44/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9613 - loss: 0.1411 - val_accuracy: 0.9618 - val_loss: 0.1486
# Epoch 45/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9613 - loss: 0.1411 - val_accuracy: 0.9618 - val_loss: 0.1486
# Epoch 45/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9603 - loss: 0.1445 - val_accuracy: 0.9618 - val_loss: 0.1439
# Epoch 46/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9603 - loss: 0.1445 - val_accuracy: 0.9618 - val_loss: 0.1439
# Epoch 46/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9625 - loss: 0.1482 - val_accuracy: 0.9618 - val_loss: 0.1432
# Epoch 47/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9625 - loss: 0.1482 - val_accuracy: 0.9618 - val_loss: 0.1432
# Epoch 47/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9652 - loss: 0.1291 - val_accuracy: 0.9618 - val_loss: 0.1458
# Epoch 48/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9652 - loss: 0.1291 - val_accuracy: 0.9618 - val_loss: 0.1458
# Epoch 48/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9630 - loss: 0.1404 - val_accuracy: 0.9618 - val_loss: 0.1432
# Epoch 49/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9630 - loss: 0.1404 - val_accuracy: 0.9618 - val_loss: 0.1432
# Epoch 49/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9592 - loss: 0.1442 - val_accuracy: 0.9618 - val_loss: 0.1420
# Epoch 50/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9592 - loss: 0.1442 - val_accuracy: 0.9618 - val_loss: 0.1420
# Epoch 50/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9676 - loss: 0.1272 - val_accuracy: 0.9618 - val_loss: 0.1423
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9676 - loss: 0.1272 - val_accuracy: 0.9618 - val_loss: 0.1423
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Convertir las etiquetas a formato categórico
num_classes = len(y2.unique())
y2_train_categorical = to_categorical(y2_train, num_classes)
y2_test_categorical = to_categorical(y2_test, num_classes)

# Crear el modelo
model = Sequential([
    Dense(128, activation='relu', input_shape=(x2_train.shape[1],)),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])

# Compilar el modelo
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Entrenar el modelo
history = model.fit(x2_train, y2_train_categorical, epochs=50, batch_size=32, validation_split=0.2)

# Generar predicciones
y2_pred = model.predict(x2_test)
y2_pred_classes = np.argmax(y2_pred, axis=1)  # Convertir predicciones a clases
y2_test_classes = np.argmax(y2_test_categorical, axis=1)  # Convertir etiquetas reales a clases

# Crear la matriz de confusión
cm = confusion_matrix(y2_test_classes, y2_pred_classes)

# Visualizar la matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(num_classes))
disp.plot(cmap='Blues')
plt.show()
# Out:
# Epoch 1/50
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.5549 - loss: 4.5794 - val_accuracy: 0.7097 - val_loss: 0.5855
# Epoch 2/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.5549 - loss: 4.5794 - val_accuracy: 0.7097 - val_loss: 0.5855
# Epoch 2/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6499 - loss: 0.7034 - val_accuracy: 0.7171 - val_loss: 0.5820
# Epoch 3/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6499 - loss: 0.7034 - val_accuracy: 0.7171 - val_loss: 0.5820
# Epoch 3/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6913 - loss: 0.6039 - val_accuracy: 0.7245 - val_loss: 0.5462
# Epoch 4/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6913 - loss: 0.6039 - val_accuracy: 0.7245 - val_loss: 0.5462
# Epoch 4/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6962 - loss: 0.5840 - val_accuracy: 0.7238 - val_loss: 0.5526
# Epoch 5/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6962 - loss: 0.5840 - val_accuracy: 0.7238 - val_loss: 0.5526
# Epoch 5/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7128 - loss: 0.5686 - val_accuracy: 0.7258 - val_loss: 0.5296
# Epoch 6/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7128 - loss: 0.5686 - val_accuracy: 0.7258 - val_loss: 0.5296
# Epoch 6/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7028 - loss: 0.5692 - val_accuracy: 0.7319 - val_loss: 0.5246
# Epoch 7/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7028 - loss: 0.5692 - val_accuracy: 0.7319 - val_loss: 0.5246
# Epoch 7/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7294 - loss: 0.5492 - val_accuracy: 0.7386 - val_loss: 0.5188
# Epoch 8/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7294 - loss: 0.5492 - val_accuracy: 0.7386 - val_loss: 0.5188
# Epoch 8/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7287 - loss: 0.5357 - val_accuracy: 0.7372 - val_loss: 0.5109
# Epoch 9/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7287 - loss: 0.5357 - val_accuracy: 0.7372 - val_loss: 0.5109
# Epoch 9/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7396 - loss: 0.5173 - val_accuracy: 0.7352 - val_loss: 0.5103
# Epoch 10/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7396 - loss: 0.5173 - val_accuracy: 0.7352 - val_loss: 0.5103
# Epoch 10/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7360 - loss: 0.5239 - val_accuracy: 0.7480 - val_loss: 0.5069
# Epoch 11/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7360 - loss: 0.5239 - val_accuracy: 0.7480 - val_loss: 0.5069
# Epoch 11/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7229 - loss: 0.5334 - val_accuracy: 0.7440 - val_loss: 0.5065
# Epoch 12/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7229 - loss: 0.5334 - val_accuracy: 0.7440 - val_loss: 0.5065
# Epoch 12/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7284 - loss: 0.5249 - val_accuracy: 0.7406 - val_loss: 0.4982
# Epoch 13/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7284 - loss: 0.5249 - val_accuracy: 0.7406 - val_loss: 0.4982
# Epoch 13/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7340 - loss: 0.5191 - val_accuracy: 0.7379 - val_loss: 0.5071
# Epoch 14/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7340 - loss: 0.5191 - val_accuracy: 0.7379 - val_loss: 0.5071
# Epoch 14/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7535 - loss: 0.5056 - val_accuracy: 0.7513 - val_loss: 0.5108
# Epoch 15/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7535 - loss: 0.5056 - val_accuracy: 0.7513 - val_loss: 0.5108
# Epoch 15/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7390 - loss: 0.5175 - val_accuracy: 0.7325 - val_loss: 0.5023
# Epoch 16/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7390 - loss: 0.5175 - val_accuracy: 0.7325 - val_loss: 0.5023
# Epoch 16/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7428 - loss: 0.5083 - val_accuracy: 0.7426 - val_loss: 0.4894
# Epoch 17/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7428 - loss: 0.5083 - val_accuracy: 0.7426 - val_loss: 0.4894
# Epoch 17/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7486 - loss: 0.4964 - val_accuracy: 0.7453 - val_loss: 0.4859
# Epoch 18/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7486 - loss: 0.4964 - val_accuracy: 0.7453 - val_loss: 0.4859
# Epoch 18/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7416 - loss: 0.5035 - val_accuracy: 0.7379 - val_loss: 0.4927
# Epoch 19/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7416 - loss: 0.5035 - val_accuracy: 0.7379 - val_loss: 0.4927
# Epoch 19/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7454 - loss: 0.4945 - val_accuracy: 0.7540 - val_loss: 0.4843
# Epoch 20/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7454 - loss: 0.4945 - val_accuracy: 0.7540 - val_loss: 0.4843
# Epoch 20/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7577 - loss: 0.4845 - val_accuracy: 0.7500 - val_loss: 0.4813
# Epoch 21/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7577 - loss: 0.4845 - val_accuracy: 0.7500 - val_loss: 0.4813
# Epoch 21/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7452 - loss: 0.4930 - val_accuracy: 0.7621 - val_loss: 0.4838
# Epoch 22/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7452 - loss: 0.4930 - val_accuracy: 0.7621 - val_loss: 0.4838
# Epoch 22/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7595 - loss: 0.4847 - val_accuracy: 0.7601 - val_loss: 0.4806
# Epoch 23/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7595 - loss: 0.4847 - val_accuracy: 0.7601 - val_loss: 0.4806
# Epoch 23/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7530 - loss: 0.4891 - val_accuracy: 0.7587 - val_loss: 0.4769
# Epoch 24/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7530 - loss: 0.4891 - val_accuracy: 0.7587 - val_loss: 0.4769
# Epoch 24/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7503 - loss: 0.4854 - val_accuracy: 0.7520 - val_loss: 0.4859
# Epoch 25/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7503 - loss: 0.4854 - val_accuracy: 0.7520 - val_loss: 0.4859
# Epoch 25/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7487 - loss: 0.4892 - val_accuracy: 0.7534 - val_loss: 0.4797
# Epoch 26/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7487 - loss: 0.4892 - val_accuracy: 0.7534 - val_loss: 0.4797
# Epoch 26/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7567 - loss: 0.4788 - val_accuracy: 0.7527 - val_loss: 0.4788
# Epoch 27/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7567 - loss: 0.4788 - val_accuracy: 0.7527 - val_loss: 0.4788
# Epoch 27/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7594 - loss: 0.4741 - val_accuracy: 0.7493 - val_loss: 0.4735
# Epoch 28/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7594 - loss: 0.4741 - val_accuracy: 0.7493 - val_loss: 0.4735
# Epoch 28/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7642 - loss: 0.4692 - val_accuracy: 0.7581 - val_loss: 0.4769
# Epoch 29/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7642 - loss: 0.4692 - val_accuracy: 0.7581 - val_loss: 0.4769
# Epoch 29/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7614 - loss: 0.4818 - val_accuracy: 0.7540 - val_loss: 0.4720
# Epoch 30/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7614 - loss: 0.4818 - val_accuracy: 0.7540 - val_loss: 0.4720
# Epoch 30/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7435 - loss: 0.4871 - val_accuracy: 0.7520 - val_loss: 0.4805
# Epoch 31/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7435 - loss: 0.4871 - val_accuracy: 0.7520 - val_loss: 0.4805
# Epoch 31/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7548 - loss: 0.4748 - val_accuracy: 0.7547 - val_loss: 0.4739
# Epoch 32/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7548 - loss: 0.4748 - val_accuracy: 0.7547 - val_loss: 0.4739
# Epoch 32/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7588 - loss: 0.4727 - val_accuracy: 0.7608 - val_loss: 0.4722
# Epoch 33/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7588 - loss: 0.4727 - val_accuracy: 0.7608 - val_loss: 0.4722
# Epoch 33/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7604 - loss: 0.4732 - val_accuracy: 0.7567 - val_loss: 0.4724
# Epoch 34/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7604 - loss: 0.4732 - val_accuracy: 0.7567 - val_loss: 0.4724
# Epoch 34/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7629 - loss: 0.4739 - val_accuracy: 0.7534 - val_loss: 0.4819
# Epoch 35/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7629 - loss: 0.4739 - val_accuracy: 0.7534 - val_loss: 0.4819
# Epoch 35/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7584 - loss: 0.4672 - val_accuracy: 0.7560 - val_loss: 0.4696
# Epoch 36/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7584 - loss: 0.4672 - val_accuracy: 0.7560 - val_loss: 0.4696
# Epoch 36/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7521 - loss: 0.4724 - val_accuracy: 0.7594 - val_loss: 0.4661
# Epoch 37/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7521 - loss: 0.4724 - val_accuracy: 0.7594 - val_loss: 0.4661
# Epoch 37/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7596 - loss: 0.4781 - val_accuracy: 0.7587 - val_loss: 0.4671
# Epoch 38/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7596 - loss: 0.4781 - val_accuracy: 0.7587 - val_loss: 0.4671
# Epoch 38/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7727 - loss: 0.4582 - val_accuracy: 0.7406 - val_loss: 0.4917
# Epoch 39/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7727 - loss: 0.4582 - val_accuracy: 0.7406 - val_loss: 0.4917
# Epoch 39/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7662 - loss: 0.4693 - val_accuracy: 0.7621 - val_loss: 0.4631
# Epoch 40/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7662 - loss: 0.4693 - val_accuracy: 0.7621 - val_loss: 0.4631
# Epoch 40/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7615 - loss: 0.4668 - val_accuracy: 0.7540 - val_loss: 0.4703
# Epoch 41/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7615 - loss: 0.4668 - val_accuracy: 0.7540 - val_loss: 0.4703
# Epoch 41/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7627 - loss: 0.4593 - val_accuracy: 0.7581 - val_loss: 0.4742
# Epoch 42/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7627 - loss: 0.4593 - val_accuracy: 0.7581 - val_loss: 0.4742
# Epoch 42/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7641 - loss: 0.4580 - val_accuracy: 0.7534 - val_loss: 0.4627
# Epoch 43/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7641 - loss: 0.4580 - val_accuracy: 0.7534 - val_loss: 0.4627
# Epoch 43/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7749 - loss: 0.4577 - val_accuracy: 0.7587 - val_loss: 0.4594
# Epoch 44/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7749 - loss: 0.4577 - val_accuracy: 0.7587 - val_loss: 0.4594
# Epoch 44/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7723 - loss: 0.4569 - val_accuracy: 0.7628 - val_loss: 0.4633
# Epoch 45/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7723 - loss: 0.4569 - val_accuracy: 0.7628 - val_loss: 0.4633
# Epoch 45/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7683 - loss: 0.4547 - val_accuracy: 0.7661 - val_loss: 0.4588
# Epoch 46/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7683 - loss: 0.4547 - val_accuracy: 0.7661 - val_loss: 0.4588
# Epoch 46/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7737 - loss: 0.4522 - val_accuracy: 0.7547 - val_loss: 0.4579
# Epoch 47/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7737 - loss: 0.4522 - val_accuracy: 0.7547 - val_loss: 0.4579
# Epoch 47/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7698 - loss: 0.4694 - val_accuracy: 0.7668 - val_loss: 0.4552
# Epoch 48/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7698 - loss: 0.4694 - val_accuracy: 0.7668 - val_loss: 0.4552
# Epoch 48/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7768 - loss: 0.4575 - val_accuracy: 0.7608 - val_loss: 0.4590
# Epoch 49/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7768 - loss: 0.4575 - val_accuracy: 0.7608 - val_loss: 0.4590
# Epoch 49/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7746 - loss: 0.4491 - val_accuracy: 0.7594 - val_loss: 0.4678
# Epoch 50/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7746 - loss: 0.4491 - val_accuracy: 0.7594 - val_loss: 0.4678
# Epoch 50/50
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7751 - loss: 0.4564 - val_accuracy: 0.7668 - val_loss: 0.4557
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7751 - loss: 0.4564 - val_accuracy: 0.7668 - val_loss: 0.4557
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Convertir las etiquetas a formato categórico
num_classes = len(y3.unique())
y3_train_categorical = to_categorical(y3_train, num_classes)
y3_test_categorical = to_categorical(y3_test, num_classes)

# Crear el modelo
model = Sequential([
    Dense(128, activation='relu', input_shape=(x3_train.shape[1],)),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])

# Compilar el modelo
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Entrenar el modelo
history = model.fit(x3_train, y3_train_categorical, epochs=50, batch_size=32, validation_split=0.2)

# Generar predicciones
y3_pred = model.predict(x3_test)
y3_pred_classes = np.argmax(y3_pred, axis=1)  # Convertir predicciones a clases
y3_test_classes = np.argmax(y3_test_categorical, axis=1)  # Convertir etiquetas reales a clases

# Crear la matriz de confusión
cm = confusion_matrix(y3_test_classes, y3_pred_classes)

# Visualizar la matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(num_classes))
disp.plot(cmap='Blues')
plt.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8790 - loss: 2.1017 - val_accuracy: 0.9548 - val_loss: 0.3685
# Epoch 2/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9035 - loss: 0.6766 - val_accuracy: 0.9548 - val_loss: 0.2506
# Epoch 3/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9406 - loss: 0.3276 - val_accuracy: 0.9548 - val_loss: 0.3211
# Epoch 4/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9431 - loss: 0.2674 - val_accuracy: 0.9548 - val_loss: 0.2728
# Epoch 5/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9522 - loss: 0.2649 - val_accuracy: 0.9548 - val_loss: 0.2374
# Epoch 6/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9507 - loss: 0.2607 - val_accuracy: 0.9548 - val_loss: 0.2593
# Epoch 7/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9542 - loss: 0.2472 - val_accuracy: 0.9548 - val_loss: 0.2194
# Epoch 8/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9510 - loss: 0.2431 - val_accuracy: 0.9548 - val_loss: 0.2422
# Epoch 9/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9597 - loss: 0.2202 - val_accuracy: 0.9548 - val_loss: 0.2235
# Epoch 10/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9588 - loss: 0.2066 - val_accuracy: 0.9548 - val_loss: 0.2111
# Epoch 11/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9456 - loss: 0.2568 - val_accuracy: 0.9548 - val_loss: 0.2000
# Epoch 12/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9581 - loss: 0.1893 - val_accuracy: 0.9548 - val_loss: 0.1977
# Epoch 13/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9563 - loss: 0.2070 - val_accuracy: 0.9548 - val_loss: 0.1956
# Epoch 14/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9485 - loss: 0.2208 - val_accuracy: 0.9548 - val_loss: 0.1941
# Epoch 15/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9554 - loss: 0.2012 - val_accuracy: 0.9548 - val_loss: 0.1948
# Epoch 16/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9579 - loss: 0.1987 - val_accuracy: 0.9548 - val_loss: 0.1950
# Epoch 17/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9506 - loss: 0.2108 - val_accuracy: 0.9548 - val_loss: 0.1880
# Epoch 18/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9503 - loss: 0.2076 - val_accuracy: 0.9548 - val_loss: 0.1872
# Epoch 19/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9529 - loss: 0.2057 - val_accuracy: 0.9548 - val_loss: 0.1798
# Epoch 20/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9541 - loss: 0.1870 - val_accuracy: 0.9548 - val_loss: 0.1854
# Epoch 21/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9496 - loss: 0.2036 - val_accuracy: 0.9548 - val_loss: 0.1758
# Epoch 22/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9582 - loss: 0.1798 - val_accuracy: 0.9548 - val_loss: 0.1755
# Epoch 23/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9546 - loss: 0.1831 - val_accuracy: 0.9548 - val_loss: 0.1720
# Epoch 24/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9529 - loss: 0.1934 - val_accuracy: 0.9548 - val_loss: 0.1754
# Epoch 25/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9515 - loss: 0.1952 - val_accuracy: 0.9548 - val_loss: 0.1704
# Epoch 26/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9529 - loss: 0.1855 - val_accuracy: 0.9548 - val_loss: 0.1683
# Epoch 27/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9536 - loss: 0.1815 - val_accuracy: 0.9548 - val_loss: 0.1672
# Epoch 28/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9512 - loss: 0.1840 - val_accuracy: 0.9548 - val_loss: 0.1754
# Epoch 29/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9506 - loss: 0.1907 - val_accuracy: 0.9548 - val_loss: 0.1686
# Epoch 30/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9488 - loss: 0.1917 - val_accuracy: 0.9548 - val_loss: 0.1669
# Epoch 31/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9546 - loss: 0.1748 - val_accuracy: 0.9548 - val_loss: 0.1643
# Epoch 32/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9572 - loss: 0.1710 - val_accuracy: 0.9548 - val_loss: 0.1655
# Epoch 33/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9533 - loss: 0.1771 - val_accuracy: 0.9548 - val_loss: 0.1612
# Epoch 34/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9575 - loss: 0.1628 - val_accuracy: 0.9548 - val_loss: 0.1591
# Epoch 35/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9552 - loss: 0.1674 - val_accuracy: 0.9548 - val_loss: 0.1618
# Epoch 36/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9559 - loss: 0.1619 - val_accuracy: 0.9548 - val_loss: 0.1641
# Epoch 37/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9444 - loss: 0.2298 - val_accuracy: 0.9548 - val_loss: 0.1639
# Epoch 38/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9539 - loss: 0.1704 - val_accuracy: 0.9548 - val_loss: 0.1577
# Epoch 39/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9565 - loss: 0.1618 - val_accuracy: 0.9548 - val_loss: 0.1571
# Epoch 40/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9569 - loss: 0.1575 - val_accuracy: 0.9548 - val_loss: 0.1567
# Epoch 41/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9518 - loss: 0.1743 - val_accuracy: 0.9548 - val_loss: 0.1564
# Epoch 42/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9498 - loss: 0.1762 - val_accuracy: 0.9548 - val_loss: 0.1562
# Epoch 43/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9494 - loss: 0.1799 - val_accuracy: 0.9548 - val_loss: 0.1566
# Epoch 44/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9521 - loss: 0.1675 - val_accuracy: 0.9548 - val_loss: 0.1572
# Epoch 45/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9516 - loss: 0.1753 - val_accuracy: 0.9548 - val_loss: 0.1558
# Epoch 46/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9536 - loss: 0.1657 - val_accuracy: 0.9548 - val_loss: 0.1565
# Epoch 47/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9575 - loss: 0.1542 - val_accuracy: 0.9548 - val_loss: 0.1574
# Epoch 48/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9526 - loss: 0.1668 - val_accuracy: 0.9548 - val_loss: 0.1576
# Epoch 49/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9575 - loss: 0.1592 - val_accuracy: 0.9548 - val_loss: 0.1556
# Epoch 50/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9534 - loss: 0.1672 - val_accuracy: 0.9548 - val_loss: 0.1585
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
# Convertir las etiquetas a formato categórico
num_classes = len(y4.unique())
y4_train_categorical = to_categorical(y4_train, num_classes)
y4_test_categorical = to_categorical(y4_test, num_classes)

# Crear el modelo
model = Sequential([
    Dense(128, activation='relu', input_shape=(x4_train.shape[1],)),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])

# Compilar el modelo
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Entrenar el modelo
history = model.fit(x4_train, y4_train_categorical, epochs=50, batch_size=32, validation_split=0.2)

# Generar predicciones
y4_pred = model.predict(x4_test)
y4_pred_classes = np.argmax(y4_pred, axis=1)  # Convertir predicciones a clases
y4_test_classes = np.argmax(y4_test_categorical, axis=1)  # Convertir etiquetas reales a clases

# Crear la matriz de confusión
cm = confusion_matrix(y4_test_classes, y4_pred_classes)

# Visualizar la matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(num_classes))
disp.plot(cmap='Blues')
plt.show()
# Out:
# Epoch 1/50
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5201 - loss: 5.4240 - val_accuracy: 0.6046 - val_loss: 0.6640
# Epoch 2/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5754 - loss: 0.8161 - val_accuracy: 0.7277 - val_loss: 0.6455
# Epoch 3/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6317 - loss: 0.6684 - val_accuracy: 0.6332 - val_loss: 0.6314
# Epoch 4/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6570 - loss: 0.6397 - val_accuracy: 0.7427 - val_loss: 0.6107
# Epoch 5/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6670 - loss: 0.6243 - val_accuracy: 0.7707 - val_loss: 0.5852
# Epoch 6/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6829 - loss: 0.6030 - val_accuracy: 0.7440 - val_loss: 0.5728
# Epoch 7/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6942 - loss: 0.5905 - val_accuracy: 0.7622 - val_loss: 0.5538
# Epoch 8/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6950 - loss: 0.5804 - val_accuracy: 0.7616 - val_loss: 0.5423
# Epoch 9/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7162 - loss: 0.5671 - val_accuracy: 0.7577 - val_loss: 0.5294
# Epoch 10/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7133 - loss: 0.5623 - val_accuracy: 0.7179 - val_loss: 0.5522
# Epoch 11/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7030 - loss: 0.5616 - val_accuracy: 0.7492 - val_loss: 0.5159
# Epoch 12/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7109 - loss: 0.5543 - val_accuracy: 0.7485 - val_loss: 0.5056
# Epoch 13/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7281 - loss: 0.5435 - val_accuracy: 0.7590 - val_loss: 0.5154
# Epoch 14/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7193 - loss: 0.5376 - val_accuracy: 0.7603 - val_loss: 0.5022
# Epoch 15/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7331 - loss: 0.5308 - val_accuracy: 0.7531 - val_loss: 0.4991
# Epoch 16/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7299 - loss: 0.5338 - val_accuracy: 0.7498 - val_loss: 0.4978
# Epoch 17/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7301 - loss: 0.5270 - val_accuracy: 0.7590 - val_loss: 0.4947
# Epoch 18/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7367 - loss: 0.5200 - val_accuracy: 0.7544 - val_loss: 0.4930
# Epoch 19/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7327 - loss: 0.5210 - val_accuracy: 0.7440 - val_loss: 0.4986
# Epoch 20/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7466 - loss: 0.5114 - val_accuracy: 0.7388 - val_loss: 0.4916
# Epoch 21/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7459 - loss: 0.5123 - val_accuracy: 0.7674 - val_loss: 0.4969
# Epoch 22/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7426 - loss: 0.5142 - val_accuracy: 0.7570 - val_loss: 0.4917
# Epoch 23/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7373 - loss: 0.5200 - val_accuracy: 0.7420 - val_loss: 0.4949
# Epoch 24/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7516 - loss: 0.4976 - val_accuracy: 0.7570 - val_loss: 0.4979
# Epoch 25/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7461 - loss: 0.5117 - val_accuracy: 0.7466 - val_loss: 0.4935
# Epoch 26/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7472 - loss: 0.5015 - val_accuracy: 0.7518 - val_loss: 0.4900
# Epoch 27/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7495 - loss: 0.4985 - val_accuracy: 0.7635 - val_loss: 0.4906
# Epoch 28/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7482 - loss: 0.4990 - val_accuracy: 0.7498 - val_loss: 0.4881
# Epoch 29/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7463 - loss: 0.5021 - val_accuracy: 0.7420 - val_loss: 0.4896
# Epoch 30/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7472 - loss: 0.5155 - val_accuracy: 0.7537 - val_loss: 0.4921
# Epoch 31/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7604 - loss: 0.4888 - val_accuracy: 0.7629 - val_loss: 0.4908
# Epoch 32/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7459 - loss: 0.5014 - val_accuracy: 0.7440 - val_loss: 0.4963
# Epoch 33/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7555 - loss: 0.4940 - val_accuracy: 0.7655 - val_loss: 0.4904
# Epoch 34/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7536 - loss: 0.4964 - val_accuracy: 0.7518 - val_loss: 0.4911
# Epoch 35/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7476 - loss: 0.4971 - val_accuracy: 0.7498 - val_loss: 0.4929
# Epoch 36/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7570 - loss: 0.5001 - val_accuracy: 0.7616 - val_loss: 0.4878
# Epoch 37/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7490 - loss: 0.4954 - val_accuracy: 0.7518 - val_loss: 0.4898
# Epoch 38/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7546 - loss: 0.4889 - val_accuracy: 0.7687 - val_loss: 0.4890
# Epoch 39/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7555 - loss: 0.4953 - val_accuracy: 0.7498 - val_loss: 0.4855
# Epoch 40/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7614 - loss: 0.4899 - val_accuracy: 0.7557 - val_loss: 0.4893
# Epoch 41/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7684 - loss: 0.4899 - val_accuracy: 0.7648 - val_loss: 0.4876
# Epoch 42/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7611 - loss: 0.4919 - val_accuracy: 0.7511 - val_loss: 0.4851
# Epoch 43/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7600 - loss: 0.4907 - val_accuracy: 0.7511 - val_loss: 0.4928
# Epoch 44/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7551 - loss: 0.4979 - val_accuracy: 0.7668 - val_loss: 0.4884
# Epoch 45/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7709 - loss: 0.4852 - val_accuracy: 0.7590 - val_loss: 0.4910
# Epoch 46/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7529 - loss: 0.4868 - val_accuracy: 0.7518 - val_loss: 0.4863
# Epoch 47/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7457 - loss: 0.5061 - val_accuracy: 0.7407 - val_loss: 0.4910
# Epoch 48/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7739 - loss: 0.4648 - val_accuracy: 0.7531 - val_loss: 0.4832
# Epoch 49/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7586 - loss: 0.4824 - val_accuracy: 0.7570 - val_loss: 0.4786
# Epoch 50/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7629 - loss: 0.4760 - val_accuracy: 0.7648 - val_loss: 0.4880
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(x1_train, y1_train)
rf_predictions = rf.predict(x1_test)

cm = yb.classifier.ConfusionMatrix(rf)
cm.fit(x1_train, y1_train)
score_naive_gaussian = cm.score(x1_test, y1_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.9460285132382892
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'RandomForestClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(x2_train, y2_train)
rf_predictions = rf.predict(x2_test)

cm = yb.classifier.ConfusionMatrix(rf)
cm.fit(x2_train, y2_train)
score_naive_gaussian = cm.score(x2_test, y2_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.9930107526881721
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'RandomForestClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(x3_train, y3_train)
rf_predictions = rf.predict(x3_test)

cm = yb.classifier.ConfusionMatrix(rf)
cm.fit(x3_train, y3_train)
score_naive_gaussian = cm.score(x3_test, y3_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.9412915851272016
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'RandomForestClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(x4_train, y4_train)
rf_predictions = rf.predict(x4_test)

cm = yb.classifier.ConfusionMatrix(rf)
cm.fit(x4_train, y4_train)
score_naive_gaussian = cm.score(x4_test, y4_test)
print(score_naive_gaussian)
cm.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0.9921834288692027
# <Axes: title={'center': 'RandomForestClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
svm = SVC(kernel='rbf', random_state=42)
svm.fit(x1_train, y1_train)
svm_predictions = svm.predict(x1_test)

cm = yb.classifier.ConfusionMatrix(svm)
cm.fit(x1_train, y1_train)
score_naive_gaussian = cm.score(x1_test, y1_test)
print(score_naive_gaussian)
cm.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# 0.9460285132382892
# <Axes: title={'center': 'SVC Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
svm = SVC(kernel='rbf', random_state=42)
svm.fit(x2_train, y2_train)
svm_predictions = svm.predict(x2_test)

cm = yb.classifier.ConfusionMatrix(svm)
cm.fit(x2_train, y2_train)
score_naive_gaussian = cm.score(x2_test, y2_test)
print(score_naive_gaussian)
cm.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# 0.7602150537634409
# <Axes: title={'center': 'SVC Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
logreg = LogisticRegression(max_iter=1000, random_state=42)
logreg.fit(x1_train, y1_train)
logreg_predictions = logreg.predict(x1_test)

cm = yb.classifier.ConfusionMatrix(logreg)
cm.fit(x1_train, y1_train)
score_naive_gaussian = cm.score(x1_test, y1_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.9460285132382892
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'LogisticRegression Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
logreg = LogisticRegression(max_iter=1000, random_state=42)
logreg.fit(x2_train, y2_train)
logreg_predictions = logreg.predict(x2_test)

cm = yb.classifier.ConfusionMatrix(logreg)
cm.fit(x2_train, y2_train)
score_naive_gaussian = cm.score(x2_test, y2_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.7741935483870968
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'LogisticRegression Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
xgb = XGBClassifier(random_state=42)
xgb.fit(x1_train, y1_train)
xgb_predictions = xgb.predict(x1_test)

cm = yb.classifier.ConfusionMatrix(xgb)
cm.fit(x1_train, y1_train)
score_naive_gaussian = cm.score(x1_test, y1_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.939918533604888
# <Axes: title={'center': 'XGBClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
xgb = XGBClassifier(random_state=42)
xgb.fit(x2_train, y2_train)
xgb_predictions = xgb.predict(x2_test)

cm = yb.classifier.ConfusionMatrix(xgb)
cm.fit(x2_train, y2_train)
score_naive_gaussian = cm.score(x2_test, y2_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.9725806451612903
# <Axes: title={'center': 'XGBClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
lgbm = LGBMClassifier(random_state=42)
lgbm.fit(x1_train, y1_train)
lgbm_predictions = lgbm.predict(x1_test)

cm = yb.classifier.ConfusionMatrix(lgbm)
cm.fit(x1_train, y1_train)
score_naive_gaussian = cm.score(x1_test, y1_test)
print(score_naive_gaussian)
cm.show()
# Out:
# [LightGBM] [Info] Number of positive: 156, number of negative: 3771
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000555 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 630
# [LightGBM] [Info] Number of data points in the train set: 3927, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.039725 -> initscore=-3.185239
# [LightGBM] [Info] Start training from score -3.185239
# 0.9419551934826884
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'LGBMClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
lgbm = LGBMClassifier(random_state=42)
lgbm.fit(x2_train, y2_train)
lgbm_predictions = lgbm.predict(x2_test)

cm = yb.classifier.ConfusionMatrix(lgbm)
cm.fit(x2_train, y2_train)
score_naive_gaussian = cm.score(x2_test, y2_test)
print(score_naive_gaussian)
cm.show()
# Out:
# [LightGBM] [Info] Number of positive: 3669, number of negative: 3769
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000651 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 626
# [LightGBM] [Info] Number of data points in the train set: 7438, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.493278 -> initscore=-0.026891
# [LightGBM] [Info] Start training from score -0.026891
# 0.9580645161290322
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'LGBMClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
adaboost = AdaBoostClassifier(n_estimators=100, random_state=42)
adaboost.fit(x1_train, y1_train)
adaboost_predictions = adaboost.predict(x1_test)

cm = yb.classifier.ConfusionMatrix(adaboost)
cm.fit(x1_train, y1_train)
score_naive_gaussian = cm.score(x1_test, y1_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.9460285132382892
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'AdaBoostClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
adaboost = AdaBoostClassifier(n_estimators=100, random_state=42)
adaboost.fit(x2_train, y2_train)
adaboost_predictions = adaboost.predict(x2_test)

cm = yb.classifier.ConfusionMatrix(adaboost)
cm.fit(x2_train, y2_train)
score_naive_gaussian = cm.score(x2_test, y2_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.7661290322580645
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'AdaBoostClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
etc = ExtraTreesClassifier(n_estimators=100, random_state=42)
etc.fit(x1_train, y1_train)
etc_predictions = etc.predict(x1_test)

cm = yb.classifier.ConfusionMatrix(etc)
cm.fit(x1_train, y1_train)
score_naive_gaussian = cm.score(x1_test, y1_test)
print(score_naive_gaussian)
cm.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but ExtraTreesClassifier was fitted with feature names
#   warnings.warn(
# 0.939918533604888
# <Axes: title={'center': 'ExtraTreesClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
etc = ExtraTreesClassifier(n_estimators=100, random_state=42)
etc.fit(x2_train, y2_train)
etc_predictions = etc.predict(x2_test) 

cm = yb.classifier.ConfusionMatrix(etc)
cm.fit(x2_train, y2_train)
score_naive_gaussian = cm.score(x2_test, y2_test)
print(score_naive_gaussian)
cm.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but ExtraTreesClassifier was fitted with feature names
#   warnings.warn(
# 0.9967741935483871
# <Axes: title={'center': 'ExtraTreesClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
# Crear el modelo Bagging con DecisionTreeClassifier como base
bagging = BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=50, random_state=42)
bagging.fit(x1_train, y1_train)
bagging_predictions = bagging.predict(x1_test)

# Visualizar la matriz de confusión con Yellowbrick
cm = yb.classifier.ConfusionMatrix(bagging)
cm.fit(x1_train, y1_train)
score_naive_gaussian = cm.score(x1_test, y1_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.9419551934826884
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but BaggingClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'BaggingClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
# Crear el modelo Bagging con DecisionTreeClassifier como base
bagging = BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=50, random_state=42)
bagging.fit(x2_train, y2_train)
bagging_predictions = bagging.predict(x2_test)

# Visualizar la matriz de confusión con Yellowbrick
cm = yb.classifier.ConfusionMatrix(bagging)
cm.fit(x2_train, y2_train)
score_naive_gaussian = cm.score(x2_test, y2_test)
print(score_naive_gaussian)
cm.show()
# Out:
# 0.989247311827957
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but BaggingClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'BaggingClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
# Crear el modelo Bagging con ExtraTreesClassifier como base
bagging = BaggingClassifier(estimator=ExtraTreesClassifier(n_estimators=100, random_state=42), 
                            n_estimators=50, random_state=42)
bagging.fit(x1_train, y1_train)
bagging_predictions = bagging.predict(x1_test)

# Visualizar la matriz de confusión con Yellowbrick
cm = ConfusionMatrix(bagging, classes=np.unique(y1_train))
cm.fit(x1_train, y1_train)
score_bagging_etc = cm.score(x1_test, y1_test)
print(f"Precisión del modelo Bagging con ETC: {score_bagging_etc}")
cm.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but BaggingClassifier was fitted with feature names
#   warnings.warn(
# Precisión del modelo Bagging con ETC: 0.9439918533604889
# <Axes: title={'center': 'BaggingClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
# Crear el modelo Bagging con ExtraTreesClassifier como base
bagging = BaggingClassifier(estimator=ExtraTreesClassifier(n_estimators=100, random_state=42), 
                            n_estimators=50, random_state=42)
bagging.fit(x2_train, y2_train)
bagging_predictions = bagging.predict(x2_test)

# Visualizar la matriz de confusión con Yellowbrick
cm = ConfusionMatrix(bagging, classes=np.unique(y2_train))
cm.fit(x2_train, y2_train)
score_bagging_etc = cm.score(x2_test, y2_test)
print(f"Precisión del modelo Bagging con ETC: {score_bagging_etc}")
cm.show()
# Out:
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but BaggingClassifier was fitted with feature names
#   warnings.warn(
# Precisión del modelo Bagging con ETC: 0.9940860215053764
# <Axes: title={'center': 'BaggingClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
print(dataset.iloc[1])
# Out:
# gender                 1.00
# age                   80.00
# hypertension           0.00
# heart_disease          1.00
# ever_married           1.00
# work_type              4.00
# Residence_type         0.00
# avg_glucose_level    105.92
# bmi                   32.50
# smoking_status         1.00
# stroke                 1.00
# Name: 2, dtype: float64

# %%
# Imprimir un ejemplo de los datos de entrada
print("Ejemplo de datos de entrada:")
print(x1_train.iloc[0])

# Crear un dato personalizado (reemplaza los valores con los que desees)
"""
'gender', 'age', 'hypertension', 'heart_disease', 'ever_married', 'work_type', 'Residence_type', 'avg_glucose_level', 'bmi', 'smoking_status'
dataset.drop("id", axis=1, inplace=True)
dataset['gender'] = dataset['gender'].map({'Male': 1, 'Female': 0, 'Other': 2})
dataset['ever_married'] = dataset['ever_married'].map({'Yes': 1, 'No': 0})
dataset['work_type'] = dataset['work_type'].map({'Private': 4, 'Self-employed': 2, 'Govt_job': 3, 'children': 1, 'Never_worked': 0})
dataset['Residence_type'] = dataset['Residence_type'].map({'Rural': 0, 'Urban': 1})
dataset['smoking_status'] = dataset['smoking_status'].map({'Unknown': 0, 'never smoked': 1, 'formerly smoked': 2, 'smokes': 3})

"""
dato_personalizado = [[1, 90, 0, 0, 0, 1, 1, 120.5, 20, 1]]  # Ejemplo

# Realizar la predicción con el modelo entrenado
prediccion = knn.predict(dato_personalizado)
print("Predicción para el dato personalizado:", prediccion)
# Out:
# Ejemplo de datos de entrada:
# gender                0.00
# age                  40.00
# hypertension          0.00
# heart_disease         0.00
# ever_married          1.00
# work_type             4.00
# Residence_type        1.00
# avg_glucose_level    65.77
# bmi                  31.20
# smoking_status        1.00
# Name: 3565, dtype: float64
# Predicción para el dato personalizado: [0]
# C:\Users\Kiki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
